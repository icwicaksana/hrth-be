# %%
# !pip install pddiktipy
# Out:
# Collecting pddiktipy
#   Downloading pddiktipy-2.0.6-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: requests>=2.25.0 in ./venv/lib/python3.12/site-packages (from pddiktipy) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.25.0->pddiktipy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.25.0->pddiktipy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.25.0->pddiktipy) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests>=2.25.0->pddiktipy) (2025.11.12)
# Downloading pddiktipy-2.0.6-py3-none-any.whl (18 kB)
# Installing collected packages: pddiktipy
# Successfully installed pddiktipy-2.0.6
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from pddiktipy import api
from pprint import pprint

# Menggunakan context manager (recommended)
with api() as client:
    # Cari mahasiswa spesifik
    mahasiswa = client.search_mahasiswa('Islam Cahya Wicaksana')
    pprint(mahasiswa)
# Out:
# INFO:pddiktipy.api:PDDIKTI API client initialized successfully
# [{'id': 'EW_CyTrCSY0v1djpIYELVxmtZz0gsRxHVEmr3pnqlMC919nSJnwAunfK-X-iaaH4cHOpLA==',
#   'nama': 'ISLAM CAHYA WICAKSANA',
#   'nama_prodi': 'TEKNIK INFORMATIKA',
#   'nama_pt': 'UNIVERSITAS DIAN NUSWANTORO',
#   'nim': 'A11202113746',
#   'sinkatan_pt': 'UDINUS'},
#  {'id': '6m9x9vGd5WyLNfuEg9xe6U48VsdVIkL6ZmqCJCIoDInYjqfGFkYFxVndlda-DqD3sHmOQg==',
#   'nama': 'CAHYA ADHI WICAKSANA',
#   'nama_prodi': 'TEKNIK SIPIL',
#   'nama_pt': 'UNIVERSITAS ISLAM SULTAN AGUNG',
#   'nim': 'MTS153130738',
#   'sinkatan_pt': 'UNISSULA'},
#  {'id': 'xgS1HRKMrSTvOh6f2J84ahHIA5dJU6LluIUt9usIzzIPkwynbCjIhi0CclEBM2u_8mpSAg==',
#   'nama': 'ARIF CAHYA WICAKSANA',
#   'nama_prodi': 'PENDIDIKAN AGAMA ISLAM',
#   'nama_pt': 'UNIVERSITAS ISLAM NEGERI SUNAN KALIJAGA',
#   'nim': '1420411127',
#   'sinkatan_pt': 'UIN SUKA'},
#  {'id': '_ZmXIjFZ5ChrFV0kaxNbHYi86He_mvFx_1HU_IMq2ByLIWsbBU4HuL1y9rJTaGHqcfUI7Q==',
#   'nama': 'ARIF CAHYA WICAKSANA',
#   'nama_prodi': 'PENDIDIKAN AGAMA ISLAM',
#   'nama_pt': 'UNIVERSITAS ISLAM NEGERI SUNAN KALIJAGA',
#   'nim': '10410118',
#   'sinkatan_pt': 'UIN SUKA'}]
